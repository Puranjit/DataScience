# %% [markdown]
# # Anaconda Tutorial
# <b>Anaconda is an "all in one" install that is extremely popular in Data Science and Machine Learning platform</b><br>
# Anaconda is a free Python distribution specifically designed for scientific computing (data science, machine learning). Anaconda is popular because it brings many of the tools used in data science and machine learning with just one install, so it's great for having short and simple setup. Anaconda uses the concept of creating environments so as to isolate different libraries and versions.
#
# ### Use of multiple environments
# - Manages the correct versions and dependenceies for your project
# - Separates different installations versions in different environments
#
# ## Install
# Go to [link](https://www.anaconda.com/products/individual-d) and download the latest installer for your machine using the instructions

# %% [markdown]
# # Follow these steps after downloading Anaconda navigator setup (Individual Edition)

# %%
# The below code is only used for displaying of image below, you don't need to run this code
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename = "Anaconda1.PNG")

# %%
# The below code is only used for displaying of image below, you don't need to run this code
Image(filename = "Anaconda2.png")

# %%
# The below code is only used for displaying of image below, you don't need to run this code
Image(filename = "Anaconda3.png")

# %% [markdown]
# ### Just complete the installations by clicking next, next... and install this software completely
#
# ## Getting started with Anaconda
#
# ### General commands - run in CMD.exe/Conda prompt
#
# Check version<br>
# `conda --version`<br>
# Check more information<br>
# `conda info`<br>
# Update conda<br>
# `conda update conda`<br>
#
# ### Manage environments
#
# Create a virtual environment<br>
# `conda create -name myenv`<br>
# Specify a specific Python version
# `conda create -name myenv Python=3.8`
# Specify specific packages that are installed
# `conda create -name myenv Python=3.8 numpy matplotlib`
#
# Activate it (Depending on your machine):
# `conda activate myenv`
#
# Your terminal will feature the current activated environment.
#
# Deactivate it (Depending on your machine):
# `conda deactivate`
#
# List all environments:
# `conda env list`
#
# Remove a specific environment
# `conda env remove -name myenv`
#
# ### Manage packages
# Install specific packages
# `conda install numpy`
# Install multiple packages with one command
# `conda install seaborn matplotlib pandas`
#
# Deinstall packages
# `conda remove numpy`
#
# List all packages in an environment
# `conda list`
#
# Update a package
# `conda update numpy`
#
# Search for packages
# `conda search numpy`
#
# Installing with pip is also possible:
# `pip install numpy`
# It is recommended to install pip in your environment and then use your local pip version. Otherwise it will try to fall back to other ones on the machine
# `conda install pip`
# `pip install numpy`
#
#
# ## Conda, Jupyter notebook and Visual Studio Code
# Conda integrates nicely into Jupyter notebook and VS Code. It can automatically detect your available conda environments and let's you specify which one you want to use.

# %% [markdown]
# ## Once anaconda navigator is completely installed, open it from your desktop and launch jupyter notebook once it opens (install jupyter notebook first, if not already installed in your anaconda navigator after installation)

# %%
# The below code is only used for displaying of image below, you don't need to run this code
Image(filename = "Anaconda4.png")

# %% [markdown]
# ## Why Jupyter Notebooks
# * Jupyter is a development environment where we can write code, display images, write down markdown notes
# * It is the most popular IDE in Data Science for exploring and analyzing data!
# * It is a great Learning and Teaching tool as well
