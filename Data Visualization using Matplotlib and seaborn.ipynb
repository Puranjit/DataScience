# %% [markdown]
# # Lab 5 - Data Visualization using Matplotlib and Seaborn
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Simple examples
m = range(10)
print(m)
n = range(10,20)
print(n)
# Out:
# range(0, 10)
# range(10, 20)

# %%
## Plotting using matplotlib (plt scatter)
plt.scatter(m, n, c = 'r')
plt.xlabel('X axis')
plt.ylabel('y axis')
plt.title('Graph in 2-D')
# Out:
# Text(0.5, 1.0, 'Graph in 2-D')

# %%
plt.savefig('Test.png')

# %%
# plt plot
n = [x*x for x in m]
n
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
plt.plot(m, n, 'r*', linestyle = 'dashed', linewidth = 2, markersize = 12)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2-D diagram')
# Out:
# Text(0.5, 1.0, '2-D diagram')

# %% [markdown]
# ### Creating sub-plots

# %%
plt.subplot(2,2,1)
plt.plot(m, n, 'r--')
plt.subplot(2,2,2)
plt.plot(m, n, 'g*--')
plt.subplot(2,2,3)
plt.plot(m, n, 'bo')
plt.subplot(2,2,4)
plt.plot(m, n, 'go')

# %%
x = range(1,11) 
y = [3*n+5 for n in x]
print(x)
print(y)
# Out:
# range(1, 11)
# [8, 11, 14, 17, 20, 23, 26, 29, 32, 35]

# %%
plt.title("Matplotlib demo") 
plt.xlabel("X axis caption") 
plt.ylabel("Y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y)

# %%
x = np.arange(-10,11)
plt.figure(figsize=(12, 6))
plt.title('My Nice Plot')

plt.subplot(1, 2, 1)  # rows, columns, panel selected
plt.plot(x, x ** 2)
plt.plot([0, 0, 0], [-10, 0, 100])
plt.legend(['X^2', 'Vertical Line'])
plt.xlabel('X')
plt.ylabel('X Squared')

plt.subplot(1, 2, 2)
plt.plot(x, -1 * (x ** 2))
plt.plot([-10, 0, 10], [-50, -50, -50])
plt.legend(['-X^2', 'Horizontal Line'])

plt.xlabel('X')
plt.ylabel('X Squared')
# Out:
# Text(0, 0.5, 'X Squared')

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.plot(x, x + 0, linestyle='solid')
axes.plot(x, x + 1, linestyle='dashed')
axes.plot(x, x + 2, linestyle='dashdot')
axes.plot(x, x + 3, linestyle='dotted');

axes.set_title("My Nice Plot")
# Out:
# Text(0.5, 1.0, 'My Nice Plot')

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.plot(x, x + 0, '-og', label="solid green")
axes.plot(x, x + 1, '--c', label="dashed cyan")
axes.plot(x, x + 2, '-.b', label="dashdot blue")
axes.plot(x, x + 3, ':r', label="dotted red")

axes.set_title("My Nice Plot")

axes.legend()

# %%
# Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')
# Out:
# Text(0.5, 1.0, 'Cosine')

# %% [markdown]
# ## Bar graph

# %%
## Bar plot

x1 = [2,8,10] 
y1 = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x1, y1) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %% [markdown]
# ## Histogram

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) 
plt.title("histogram")
# Out:
# Text(0.5, 1.0, 'histogram')

# %% [markdown]
# ## Box plot using matplot-lib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False);

# %%
data
# Out:
# [array([ 0.41575897,  1.79867251,  0.76425937,  0.41459109,  1.91444233,
#         -0.92499057,  0.98188566, -0.44072746, -1.28641517,  0.36113823,
#          1.02833683,  0.04782185, -0.9613362 ,  2.03692185,  1.11251781,
#         -0.30229161, -1.76723955, -0.58029995, -0.46621764, -0.40048107,
#          0.55296302, -0.96255217, -0.06929456,  0.65146277,  0.98843346,
#         -1.06256877, -0.33417061, -1.12255964, -0.46914605,  1.30158345,
#         -1.93564774e+00,  7.47917136e-01, -3.57927141e+00, -4.55525706e+00,
#         -4.84473529e-01, -4.74328035e+00,  2.19649909e+00, -7.21365936e-01,
#          2.76938095e+00, -5.58654664e+00, -2.87544747e+00, -3.55429152e-02,
#          3.02977376e+00, -4.02482013e+00, -1.01150323e+00, -4.57798674e+00,
#         -3.05667092e+00, -5.43465373e+00,  8.27939516e-01,  2.73605563e+00,
#         -3.15512734e+00,  4.84140097e+00, -1.85509858e+00, -1.60445144e+00,
#          1.37205273e+00,  4.62386554e+00,  2.07751291e+00, -4.14341196e+00,
#          2.01520843e+00,  5.15697200e+00,  2.03810566e+00,  2.28350828e+00,
#          3.04252171e+00, -2.41243131e+00,  4.68769584e+00, -5.06444910e+00,
#          2.50100337e+00,  2.03768796e+00, -4.89483145e-01,  6.39027765e-01,
#          2.48708550e+00, -4.55632828e+00,  7.47604233e-01,  1.38604923e+00,
#         -5.29978968e+00, -1.19230073e+00,  1.41207560e-01,  6.69930769e+00,
#          3.49946558e+00,  1.82820480e+00, -3.08189189e+00,  1.92146753e+00,
#          1.41290329e+00, -9.66035151e-01, -1.05297429e+00, -1.85863540e+00,
#          4.34096545e+00,  4.59794421e+00,  4.43882532e+00,  3.18579690e+00,
#         -6.74704810e+00,  4.90529996e+00, -9.28116155e-03,  2.42314757e-01,
#         -5.23938734e+00,  3.26483754e+00, -7.40571471e-01,  3.59704383e+00,
#         -7.64260328e-02, -3.81191021e+00, -8.96358033e-02,  3.05547033e+00,
#          8.55006045e-01,  2.74303320e-01, -4.66305963e+00,  3.58884885e+00,
#          6.06315913e-03,  1.39964526e+00, -2.63174508e+00, -4.18468287e+00])]

# %% [markdown]
# ## Pie chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Seaborn
# Seaborn helps us make our plots more attractive and delightful using various themes and color-pallettes

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = sns.load_dataset('flights')

# %%
a
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x = 'passengers', y = 'month', data = a)

# %%
sns.relplot(x = 'passengers', y = 'month', data = a, hue = 'year')

# %%
b = sns.load_dataset('tips')

# %%
sns.relplot(x = 'time', y = 'tip', data = b, kind = 'line')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = b)

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = b)

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', data = b)

# %% [markdown]
# ### Univariate distributioon

# %%
from scipy import stats
c = np.random.normal(loc = 5, size = 100, scale = 2)
sns.distplot(c)
# Out:
# C:\Users\psingh24\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Bivariate distributioon

# %%
a = sns.load_dataset('iris')
b = sns.FacetGrid(a, col = 'species')
b.map(plt.hist, 'sepal_length')

# %%
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
a = sns.load_dataset('flights')
b = sns.PairGrid(a)
b.map(plt.scatter)

# %%
a
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.set(style = 'darkgrid')
a = sns.load_dataset('flights')
b = sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style = 'white', color_codes = True)
a = sns.load_dataset('tips')
sns.boxplot(x = 'day', y = 'total_bill', data = a)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set(style = 'white', color_codes = True)
a = sns.load_dataset('tips')
sns.boxplot(x = 'day', y = 'total_bill', data = a)
sns.despine(offset = 10, trim = True)

# %% [markdown]
# ## Color-pallettes

# %%
c = sns.color_palette()
sns.palplot(c)
